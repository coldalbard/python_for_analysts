# %% [markdown]
# ## Условие 1: Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы

# %% [markdown]
# ### 1.1. Скачать следующие данные: kc-house-data и laptop_price

# %%
import pandas as pd
import matplotlib.pyplot as plt
house = pd.read_csv('/gb/analitcPython/homework/homework4/kc_house_data.csv', sep=',', encoding='windows-1251')
laptops = pd.read_csv('/gb/analitcPython/homework/homework4/laptop_price.csv', sep=',', encoding='windows-1251')

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(10, 5))
plt.hist(house['price'])
plt.title("График количества домов по ценам")
plt.xlabel("Цена")
plt.ylabel("Количество")
plt.xticks(rotation=-90);

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой

# %%
plt.hist(house['sqft_living'])
plt.xlabel('Квадратура')
plt.ylabel('Количество')
plt.title('Гистограмма квадратуры домов');

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
plt.hist(house['yr_built'])
plt.xlabel('Год постройки')
plt.ylabel('Количество')
plt.title('Гистограмма по годам постройки');
